# %% [markdown]
# ### === Purpose ===
#
# The goal of this lab is to perform relation classification on a text where NER and Disambiguation were performed. For example, given a Wikipedia article:
#
#     <Elvis_Presley>
#     <Elvis_Presley> was an <United_States_of_America> singer and actor, married to <Priscilla_Presley>.
#
# the goal is to predict the relation between the title entity and the others:
#
#     <Elvis_Presley><nationality><United_States_of_America>
#     <Elvis_Presley><spouse><Priscilla_Presley>
#
# You will use a Language Model for this task, and make use of Constrained Decoding in order to make the predictions.
#
# === Provided Data ===
#
# We provide
# 1. A preprocessed version of Wikipedia, wikipedia-ner.txt, which contains articles about disambiguated entities, whose content also went through NERC and Disambiguation.
# 2. A gold standard for the task, student-gold-standard.tsv, which contains triples <subject_entity> <object_entity> <relation>, that you will use to evaluate your method
# 3. a template for your code, relation_classification.py
#
# ### === Task ===
#
# You will have two tasks in this lab.
# The first will be to complete the function construct_trie, so that it constructs a trie for the (tokenized) list of relations given as input.
# Your second task is to complete the function classify_relation in this file.
# It receives as input (1) the title entity (subject), (2) the article content, (3) a trie.
# It outputs a list of relations between the title entity and all the other disambiguated entities in the article content. It uses Language Models and Constrained Decoding.

# %%
"""
Install necessary modules, run only once !
"""
# !pip install -q transformers
# !pip install -q sentencepiece
# !pip install -q accelerate

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch
from collections import defaultdict
import time
from tqdm import tqdm
import re
from typing import Dict, List

# %%
"""
Loads a T5 LLM
"""
torch.cuda.empty_cache()
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-large")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-large", device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
class WikipediaArticle:
  """ Represents a Wikipedia article. Do not modify. """
  def __init__(self, title, content):
    self.title_entity=title
    self.content=content

def wikipediaArticles(file):
  """ Yields the Wikipedia articles from a file. Do not modify. """
  article=[]
  title=None
  with open(file, "rt", encoding="utf=8") as inputFile:
    for line in inputFile:
      line=line.rstrip()
      if not title:
        title=line
        continue
      if not len(line) and title and len(article):
        yield WikipediaArticle(title, article[0])
        title=None
        article=[]
        continue
      article+=[line]

def clean(yagoEntity):
    """ Removes prefixes etc."""
    if yagoEntity.startswith('"'):
      return yagoEntity[1:-1]
    yagoEntity=yagoEntity[yagoEntity.find(':')+1:]
    return '<'+yagoEntity+'>'

# %%
def run_evaluation():
  """Evaluation script, do not modify (unless you want to remove some prints).
  We use the f-05 measure, which gives more importance to precision: classifying entities correctly is more valued than finding all entities.
  """
  with open("student-gold-standard.tsv", "r", encoding="utf-8") as f:
    lines = f.readlines()
  gold_standard_dict = defaultdict(dict)
  for line in lines:
    title_entity, entity_id, relation = tuple(line.replace("\n","").split("\t"))
    gold_standard_dict[title_entity][entity_id] = relation
  gold_standard_dict = dict(gold_standard_dict)

  with open("results.tsv", "r", encoding="utf-8") as f:
    lines = f.readlines()
  predictions_dict = defaultdict(dict)
  for line in lines:
    title_entity, entity_id, relation = tuple(line.replace("\n","").split("\t"))
    predictions_dict[title_entity][entity_id] = relation

  true_pos = 0
  false_pos = 0
  false_neg = 0

  for title_entity in predictions_dict:
    for entity_id in predictions_dict[title_entity]:
      try:
        gold_yago_relation = gold_standard_dict[title_entity][entity_id]
      except KeyError: #should not happen
        continue
      if predictions_dict[title_entity][entity_id] == gold_yago_relation:
        true_pos += 1
      else:
        false_pos += 1
        if false_pos < 100:
          print("You classified the relation between", title_entity + " and " + entity_id, "wrong.", "Expected output: ", gold_yago_relation, ",given:", predictions_dict[title_entity][entity_id])

  for gold_title in gold_standard_dict: #do we really want to measure this? There are some entities that don't have a wikipedia article, so they count. Should they be removed from the gold standard?
    for entity_id in gold_standard_dict[gold_title]:
      try:
        predict_relation = predictions_dict[gold_title][entity_id]
      except KeyError:
        false_neg += 1
        if false_neg < 100:
          print("You did not classify the relation between", gold_title + " and " + entity_id +".")

  if true_pos + false_pos != 0:
    precision = float(true_pos) / (true_pos + false_pos)
  else:
    precision = 0.0

  if true_pos + false_neg != 0:
    recall = float(true_pos) / (true_pos + false_neg)
  else:
    recall = 0.0

  beta = 0.5

  if precision + recall != 0.0:
    f05 = (1 + beta * beta) * precision * recall / (beta * beta * precision + recall)
  else:
    f05 = 0.0

  print()
  print("Scores (scaled from 0 to 100)")
  print("Precision", precision*100)
  print("Recall", recall*100)
  print("F-0.5 Score", f05*100)

# %%
def get_all_relations(file):
  with open(file, "r", encoding="utf-8") as f:
    lines = f.readlines()
  relations = set()
  for line in lines:
    title_entity, entity_id, relation = tuple(line.replace("\n","").split("\t"))
    relations.add(relation)
  return relations

# %%
def prefix_allowed_tokens_fn(input_ids, trie):
  '''
  The function that handles constrained decoding.
  For the current generated text, returns the following allowed tokens. If nothing is allowed, return EOS token (ends the generation).
  This function is called at every generation step (every time a token is generated)
  DO NOT MODIFY (unless you're brave)
  '''
  model_output = input_ids.tolist()
  allowed_tokens = trie.get(model_output)
  if not allowed_tokens:
    return [tokenizer.eos_token_id]
  return allowed_tokens

# %%
class Trie(object):
    def __init__(self, sequences: List[List[int]] = []):
        self.trie_dict = {}
        if sequences:
            for sequence in sequences:
                Trie._add_to_trie(sequence, self.trie_dict)

    def add(self, sequence: List[int]):
        Trie._add_to_trie(sequence, self.trie_dict)

    def get(self, prefix_sequence: List[int]):
        return Trie._get_from_trie(prefix_sequence, self.trie_dict)

    @staticmethod
    def _add_to_trie(sequence: List[int], trie_dict: Dict):
        if sequence:
            if sequence[0] not in trie_dict:
                trie_dict[sequence[0]] = {}
            Trie._add_to_trie(sequence[1:], trie_dict[sequence[0]])

    @staticmethod
    def _get_from_trie(prefix_sequence: List[int], trie_dict: Dict):
        if len(prefix_sequence) == 0:
            output = list(trie_dict.keys())
            return output
        elif prefix_sequence[0] in trie_dict:
            return Trie._get_from_trie(prefix_sequence[1:],trie_dict[prefix_sequence[0]])
        else:
            return []

    def __iter__(self):
        def _traverse(prefix_sequence, trie_dict):
            if trie_dict:
                for next_token in trie_dict:
                    yield from _traverse(prefix_sequence + [next_token], trie_dict[next_token])
            else:
                yield prefix_sequence

        return _traverse([], self.trie_dict)

    def __getitem__(self, value):
        return self.get(value)

# %%
def construct_trie(relations: List[str], tokenizer):
    """
    Constructs a Trie for the list of relations and the tokenizer provided.
    Ensures token IDs are correctly encoded and includes <pad> at the start.
    """
    trie = Trie()
    for relation in relations:
        token_ids = tokenizer.encode(relation)
        trie.add([tokenizer.pad_token_id] + token_ids)  # Add <pad> at the start
    return trie

# %%
def run_model(prompt, trie):
  """
  Runs the language model using constrained decoding
  Input:
  - Prompt (str)
  - prefix_allowed_tokens_fn
  """
  device = "cuda" if torch.cuda.is_available() else "cpu"
  input_text = prompt
  inputs = tokenizer(input_text, return_tensors="pt").input_ids.to(device)

  outputs = model.generate(inputs, max_new_tokens=20, do_sample=False, num_beams=5, temperature=None, top_p=None, pad_token_id=tokenizer.eos_token_id,
        prefix_allowed_tokens_fn=lambda _, input_ids: prefix_allowed_tokens_fn(input_ids, trie))
  return(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
import re

def classify_relations(title_entity, page_content, trie):
    """ Disambiguates the entity name based on the Wikipedia article
    Returns a list of triples (title_entity, obj_entity, relation) or (title_entity, obj_entity, None)
    In the Wikipedia article, the title entity and the object entities are surrounded by "<" and ">"
    """
    triples = []

    # Full relation list
    full_relation_list = [
        '<birthPlace>', '<founder>', '<worksFor>', '<appearsIn>', '<musicBy>',
        '<actor>', '<productionCompany>', '<playsIn>', '<author>', '<director>',
        '<alumniOf>', '<homeLocation>', '<memberOf>', '<contentLocation>', '<location>',
        '<owns>', '<locationCreated>', '<manufacturer>', '<neighbors>', '<deathPlace>',
        '<deathDate>', '<children>', '<nationality>', '<award>', '<dateCreated>',
        '<about>', '<birthDate>'
    ]

    date_related_relations = ['<deathDate>', '<dateCreated>', '<birthDate>']

    # Extract entities from page_content (entities are surrounded by "<" and ">")
    entities = re.findall(r"<[^>]+>", page_content)

    # Filter out the title_entity itself
    obj_entities = [entity for entity in entities if entity != title_entity]

    # Generate relation for each obj_entity
    for obj_entity in obj_entities:
        # Detect if obj_entity is date-like or numeric
        is_date_like = bool(re.match(r"<\d{4}(-\d{2}){0,2}(T\d{2}:\d{2}:\d{2}Z)?>", obj_entity))

        # Use specific relation list if obj_entity is date-like
        relation_list = date_related_relations if is_date_like else full_relation_list
        relation_options = ', '.join(relation_list)

        # Create a T5 input prompt for each obj_entity
        prompt = f"""
        Context: {page_content}

        Task: Identify the relationship between the following entities.

        Entity 1: {title_entity}
        Entity 2: {obj_entity}

        Relation (choose from [{relation_options}]):

        """
        print(prompt)
        # Generate relation using the provided run_model function
        try:
            relation = run_model(prompt, trie)
            relation = relation.strip("<>").strip()  # Clean the relation to remove extra brackets if any

        except Exception as e:
            print(f"Error during generation for {title_entity} and {obj_entity}: {e}")
            print(f"Prompt was: {prompt}")
            relation = "unknown_relation"

        # Append the triple
        if relation:
            triples.append((title_entity, obj_entity, relation))
        else:
            triples.append((title_entity, obj_entity, None))

    return triples

# %%
def run():
  relations = get_all_relations("student-gold-standard.tsv")
  trie = construct_trie(relations, tokenizer) #function to complete
  with open("results_4.tsv", 'a', encoding="utf-8") as output:
    start = time.time()
    for i, page in enumerate(wikipediaArticles("wikipedia-ner.txt")):
      print("  Processing",page.title_entity, i)
      result = classify_relations(page.title_entity, page.content, trie) #function to complete
      if result is not None:
        for subj, obj, rel in result:
          output.write(subj +"\t" + obj + "\t" + clean(rel) + "\n")
  end = time.time()
  print("done")
  print("execution time: ", end - start)
  print("number of articles: ", i)
run()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Entity 1: <Supergirl__u0028_Cir-El_u0029_>
#         Entity 2: <Superman__u0028_comic_book_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Power_Girl> 141
#
#         Context: <Power_Girl>, also known as Kara Zor-L and Karen Starr, is a fictional DC Comics superheroine, making her first appearance in <All_Star_Comics> #58 (January/February 1976).Who’s Who in the DC Universe #18  Power Girl is the cousin of DC's flagship hero Superman, but from an alternative universe in the fictional multiverse in which DC Comics stories are set. <Power_Girl>, also known as Kara Zor-L and Karen Starr, is a fictional DC Comics superheroine, making her first appearance in <All_Star_Comics> #58 (January/February 1976).Who’s Who in the DC Universe #18  Power Girl is the cousin of DC's flagship hero Superman, but from an alternative universe in the fictional multiverse in which DC Comics stories are set.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Power_Girl>
#         Entity 2: <All_Star_Comics>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Supergirl> 142
#
#         Context: <Supergirl> is the name of several fictional superheroine characters appearing in <United_States> comic books published by DC Comics. <Supergirl> is the name of several fictional superheroine characters appearing in <United_States> comic books published by DC Comics.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl>
#         Entity 2: <United_States>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Supergirl> is the name of several fictional superheroine characters appearing in <United_States> comic books published by DC Comics. The original and most well known Supergirl is Kara Zor-El, also known as the cousin of the superhero <Superman__u0028_comic_book_u0029_>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl>
#         Entity 2: <Superman__u0028_comic_book_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Supergirl> is the name of several fictional superheroine characters appearing in <United_States> comic books published by DC Comics. The character made her first appearance in <Action_Comics> #252  and was created by Otto Binder and Al Plastino.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl>
#         Entity 2: <Action_Comics>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Supergirl> is the name of several fictional superheroine characters appearing in <United_States> comic books published by DC Comics. DC Comics subsequently rebooted the continuity of the DC Comics Universe, re- establishing Superman's character as the sole survivor of <Krypton__u0028_comics_u0029_>'s destruction.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl>
#         Entity 2: <Krypton__u0028_comics_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Supergirl__u0028_Matrix_u0029_> 143
#
#         Context: Matrix is a fictional comic book superheroine, best known as the 1988-2002 <Supergirl__u0028_Matrix_u0029_>, published by DC Comics. She was created by <John_Byrne__u0028_comics_u0029_> as part of his <Superman__u0028_comic_book_u0029_> revamp.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl__u0028_Matrix_u0029_>
#         Entity 2: <John_Byrne__u0028_comics_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: Matrix is a fictional comic book superheroine, best known as the 1988-2002 <Supergirl__u0028_Matrix_u0029_>, published by DC Comics. She was created by <John_Byrne__u0028_comics_u0029_> as part of his <Superman__u0028_comic_book_u0029_> revamp.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl__u0028_Matrix_u0029_>
#         Entity 2: <Superman__u0028_comic_book_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Supergirl__u0028_Saving_Jane_song_u0029_> 144
#
#         Context: <Supergirl__u0028_Saving_Jane_song_u0029_> is a song written by Marti Dodson and Mats Valentin and recorded by American rock band Saving Jane for their album of the same name (<2008-01-01T00:00:00Z>). <Supergirl__u0028_Saving_Jane_song_u0029_> is a song written by Marti Dodson and Mats Valentin and recorded by American rock band Saving Jane for their album of the same name (<2008-01-01T00:00:00Z>).
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Supergirl__u0028_Saving_Jane_song_u0029_>
#         Entity 2: <2008-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Material__u0028_band_u0029_> 145
#
#         Context: <Material__u0028_band_u0029_> is a musical group formed in <1979-01-01T00:00:00Z> and led by bass guitarist <Bill_Laswell>. <Material__u0028_band_u0029_> is a musical group formed in <1979-01-01T00:00:00Z> and led by bass guitarist <Bill_Laswell>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Material__u0028_band_u0029_>
#         Entity 2: <1979-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#
#         Context: <Material__u0028_band_u0029_> is a musical group formed in <1979-01-01T00:00:00Z> and led by bass guitarist <Bill_Laswell>. <Material__u0028_band_u0029_> is a musical group formed in <1979-01-01T00:00:00Z> and led by bass guitarist <Bill_Laswell>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Material__u0028_band_u0029_>
#         Entity 2: <Bill_Laswell>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Material__u0028_film_u0029_> 146
#
#         Context: <Material__u0028_film_u0029_> is a 2012 South African film,Official website directed by Craig Freimond and written by Craig Freimond, Ronnie Apteker, Robbie Thorpe, Rosalind Butler and <Riaad_Moosa>. <Material__u0028_film_u0029_> is a 2012 South African film,Official website directed by Craig Freimond and written by Craig Freimond, Ronnie Apteker, Robbie Thorpe, Rosalind Butler and <Riaad_Moosa>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Material__u0028_film_u0029_>
#         Entity 2: <Riaad_Moosa>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Material__u0028_film_u0029_> is a 2012 South African film,Official website directed by Craig Freimond and written by Craig Freimond, Ronnie Apteker, Robbie Thorpe, Rosalind Butler and <Riaad_Moosa>. After playing at <2012-01-01T00:00:00Z> it has been shown at numerous film festivals around the world (London, International Film Festival of India, Busan) and gained a reputation as one of the best original South African films"One of the best original South African films" incwajana.com and a significant leap forward for the country's film industry.Stopforth, Mike "A Leap Forward in South African Cinema mikestopforth.com, 20, February 2012 Its portrayal of the lives of Muslims in <South_Africa> was seen as an honest attempt to tackle some of the social issues facing the country's multiracial society."South African film makes UK viewers cry" Channel 24 Entertainment Now, 3 December 2012"Telling South Africa's Stories" Brand South Africa, 2 May 2013"South African Muslims come to life in Material film" Reuters blog, 11 March 2012The Africa Channel
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Material__u0028_film_u0029_>
#         Entity 2: <2012-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#
#         Context: <Material__u0028_film_u0029_> is a 2012 South African film,Official website directed by Craig Freimond and written by Craig Freimond, Ronnie Apteker, Robbie Thorpe, Rosalind Butler and <Riaad_Moosa>. After playing at <2012-01-01T00:00:00Z> it has been shown at numerous film festivals around the world (London, International Film Festival of India, Busan) and gained a reputation as one of the best original South African films"One of the best original South African films" incwajana.com and a significant leap forward for the country's film industry.Stopforth, Mike "A Leap Forward in South African Cinema mikestopforth.com, 20, February 2012 Its portrayal of the lives of Muslims in <South_Africa> was seen as an honest attempt to tackle some of the social issues facing the country's multiracial society."South African film makes UK viewers cry" Channel 24 Entertainment Now, 3 December 2012"Telling South Africa's Stories" Brand South Africa, 2 May 2013"South African Muslims come to life in Material film" Reuters blog, 11 March 2012The Africa Channel
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Material__u0028_film_u0029_>
#         Entity 2: <South_Africa>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Material__u0028_Blaqk_Audio_album_u0029_> 147
#   Processing <Material__u0028_Aco_album_u0029_> 148
#   Processing <Material__u0028_Casiopea_album_u0029_> 149
#
#         Context: <Material__u0028_Casiopea_album_u0029_> is the thirty-second album by the jazz fusion group Casiopea, recorded and released in <1999-05-19T00:00:00Z>. <Material__u0028_Casiopea_album_u0029_> is the thirty-second album by the jazz fusion group Casiopea, recorded and released in <1999-05-19T00:00:00Z>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Material__u0028_Casiopea_album_u0029_>
#         Entity 2: <1999-05-19T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Dororo__u0028_2019_TV_series_u0029_> 150
#
#         Context: The 2019 <Dororo__u0028_2019_TV_series_u0029_> anime series is based on the manga of the same name by Osamu Tezuka. The adaptation departs from the source material in several ways, but follows the basic premise of the manga; A young ronin named Hyakkimaru along with a young urchin, Dororo, must face multiple demons in Sengoku-era <Japan> who have stolen his various body parts in order to get them back.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dororo__u0028_2019_TV_series_u0029_>
#         Entity 2: <Japan>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: The 2019 <Dororo__u0028_2019_TV_series_u0029_> anime series is based on the manga of the same name by Osamu Tezuka. <Kazuhiro_Furuhashi> directs the series, with Yasuko Kobayashi handling series composition, Satoshi Iwataki handling character designs, and Yoshihiro Ike composing the music.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dororo__u0028_2019_TV_series_u0029_>
#         Entity 2: <Kazuhiro_Furuhashi>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Dororo> 151
#
#         Context: is a Japanese manga series written and illustrated by the manga artist <Osamu_Tezuka>. is a Japanese manga series written and illustrated by the manga artist <Osamu_Tezuka>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dororo>
#         Entity 2: <Osamu_Tezuka>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <If_Not_for_You> 152
#
#         Context: <If_Not_for_You> is a song by Bob Dylan, recorded for his <1970-10-19T00:00:00Z> album New Morning. <If_Not_for_You> is a song by Bob Dylan, recorded for his <1970-10-19T00:00:00Z> album New Morning.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <If_Not_for_You>
#         Entity 2: <1970-10-19T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <If_Not_for_You__u0028_album_u0029_> 153
#
#         Context: <If_Not_for_You__u0028_album_u0029_> is the debut studio album by British-Australian singer- songwriter Olivia Newton-John, released in <1971-11-01T00:00:00Z> by Festival Records. <If_Not_for_You__u0028_album_u0029_> is the debut studio album by British-Australian singer- songwriter Olivia Newton-John, released in <1971-11-01T00:00:00Z> by Festival Records.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <If_Not_for_You__u0028_album_u0029_>
#         Entity 2: <1971-11-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <If_Not_for_You__u0028_George_Jones_song_u0029_> 154
#
#         Context: <If_Not_for_You__u0028_George_Jones_song_u0029_> is a song written by Jerry Chesnut and recorded by American country singer George Jones. 6 on the Billboard country singles chart in <1969-01-01T00:00:00Z>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <If_Not_for_You__u0028_George_Jones_song_u0029_>
#         Entity 2: <1969-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Juan_Álvarez__u0028_historian_u0029_> 155
#
#         Context: Bust of the founder, by Erminio Blotta, at the secondary entrance (Garden Library) <Rosario_u002C__Santa_Fe>, Argentina <Juan_Álvarez__u0028_historian_u0029_> (3 September 1878 - 8 April 1954) was a judge and historian born in <Gualeguaychú_u002C__Entre_Ríos>, . Bust of the founder, by Erminio Blotta, at the secondary entrance (Garden Library) <Rosario_u002C__Santa_Fe>, Argentina <Juan_Álvarez__u0028_historian_u0029_> (3 September 1878 - 8 April 1954) was a judge and historian born in <Gualeguaychú_u002C__Entre_Ríos>, .
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Juan_Álvarez__u0028_historian_u0029_>
#         Entity 2: <Rosario_u002C__Santa_Fe>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: Bust of the founder, by Erminio Blotta, at the secondary entrance (Garden Library) <Rosario_u002C__Santa_Fe>, Argentina <Juan_Álvarez__u0028_historian_u0029_> (3 September 1878 - 8 April 1954) was a judge and historian born in <Gualeguaychú_u002C__Entre_Ríos>, . Bust of the founder, by Erminio Blotta, at the secondary entrance (Garden Library) <Rosario_u002C__Santa_Fe>, Argentina <Juan_Álvarez__u0028_historian_u0029_> (3 September 1878 - 8 April 1954) was a judge and historian born in <Gualeguaychú_u002C__Entre_Ríos>, .
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Juan_Álvarez__u0028_historian_u0029_>
#         Entity 2: <Gualeguaychú_u002C__Entre_Ríos>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Vertigo__u0028_1951_film_u0029_> 156
#
#         Context: <Vertigo__u0028_1951_film_u0029_> (Spanish: Vértigo) is a 1951 Spanish drama film directed by <Eusebio_Fernández_Ardavín> and starring Fernando Granada, <Ana_Mariscal> and <Lina_Yegros>.España p.368 <Vertigo__u0028_1951_film_u0029_> (Spanish: Vértigo) is a 1951 Spanish drama film directed by <Eusebio_Fernández_Ardavín> and starring Fernando Granada, <Ana_Mariscal> and <Lina_Yegros>.España p.368
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo__u0028_1951_film_u0029_>
#         Entity 2: <Eusebio_Fernández_Ardavín>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Vertigo__u0028_1951_film_u0029_> (Spanish: Vértigo) is a 1951 Spanish drama film directed by <Eusebio_Fernández_Ardavín> and starring Fernando Granada, <Ana_Mariscal> and <Lina_Yegros>.España p.368 <Vertigo__u0028_1951_film_u0029_> (Spanish: Vértigo) is a 1951 Spanish drama film directed by <Eusebio_Fernández_Ardavín> and starring Fernando Granada, <Ana_Mariscal> and <Lina_Yegros>.España p.368
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo__u0028_1951_film_u0029_>
#         Entity 2: <Ana_Mariscal>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Vertigo__u0028_1951_film_u0029_> (Spanish: Vértigo) is a 1951 Spanish drama film directed by <Eusebio_Fernández_Ardavín> and starring Fernando Granada, <Ana_Mariscal> and <Lina_Yegros>.España p.368 <Vertigo__u0028_1951_film_u0029_> (Spanish: Vértigo) is a 1951 Spanish drama film directed by <Eusebio_Fernández_Ardavín> and starring Fernando Granada, <Ana_Mariscal> and <Lina_Yegros>.España p.368
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo__u0028_1951_film_u0029_>
#         Entity 2: <Lina_Yegros>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Vertigo_Records> 157
#
#         Context: <Vertigo_Records> is a record company, which originated in the United Kingdom. It was a subsidiary of the Philips/Phonogram record label, launched in <1969-01-01T00:00:00Z> to specialise in progressive rock and other non-mainstream musical styles.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo_Records>
#         Entity 2: <1969-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Dizziness__u0028_film_u0029_> 158
#
#         Context: <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>. <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dizziness__u0028_film_u0029_>
#         Entity 2: <Antonio_Momplet>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>. <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dizziness__u0028_film_u0029_>
#         Entity 2: <María_Félix>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>. <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dizziness__u0028_film_u0029_>
#         Entity 2: <Emilio_Tuero>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>. <Dizziness__u0028_film_u0029_> is a 1946 Mexican drama film directed by <Antonio_Momplet>, starring <María_Félix>, <Emilio_Tuero> and <Lilia_Michel>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Dizziness__u0028_film_u0029_>
#         Entity 2: <Lilia_Michel>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Vertigo__u0028_Billie_Myers_album_u0029_> 159
#   Processing <Vertigo__u0028_UTS_u0029_> 160
#
#         Context: <Vertigo__u0028_UTS_u0029_> is the student magazine of the University of Technology, Sydney.UTS Handbook, UTS Handbook, Retrieved 22 March 2007 Its name derives from the university's main building, which is a 28-storey brutal modernist tower block, and how the Vertigo Offices were originally at its summit. Vertigo is published by the UTS Students' Association.UTS Students Association, UTS Students Association Department, Retrieved 22 March 2007UTS Open Day, UTS Students Association, Retrieved 22 March 2007 The name Vertigo was adopted in <1991-01-01T00:00:00Z>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo__u0028_UTS_u0029_>
#         Entity 2: <1991-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Vertigo__u0028_wordless_novel_u0029_> 161
#
#         Context: A rainstorm spoils a young couple's carefree trip to an amusement park in 1929, foreshadowing the Great Depression to come. <Vertigo__u0028_wordless_novel_u0029_> is a wordless novel by American artist Lynd Ward (1905–1985), published in <1937-01-01T00:00:00Z>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo__u0028_wordless_novel_u0029_>
#         Entity 2: <1937-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Vertigo__u0028_Jackie_McLean_album_u0029_> 162
#
#         Context: <Vertigo__u0028_Jackie_McLean_album_u0029_> is an album by American saxophonist Jackie McLean recorded in 1962 and 1963 but not released on the Blue Note label until <1980-01-01T00:00:00Z>.Jackie McLean discography, accessed October 15, 2010. <Vertigo__u0028_Jackie_McLean_album_u0029_> is an album by American saxophonist Jackie McLean recorded in 1962 and 1963 but not released on the Blue Note label until <1980-01-01T00:00:00Z>.Jackie McLean discography, accessed October 15, 2010.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Vertigo__u0028_Jackie_McLean_album_u0029_>
#         Entity 2: <1980-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Angers_SCO> 163
#
#         Context: <Angers> Sporting Club de l'Ouest, commonly referred to as <Angers_SCO> or simply Angers , is a French professional football club based in Angers in Pays de la Loire in western <France>. <Angers> Sporting Club de l'Ouest, commonly referred to as <Angers_SCO> or simply Angers , is a French professional football club based in Angers in Pays de la Loire in western <France>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers_SCO>
#         Entity 2: <Angers>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Angers> Sporting Club de l'Ouest, commonly referred to as <Angers_SCO> or simply Angers , is a French professional football club based in Angers in Pays de la Loire in western <France>. <Angers> Sporting Club de l'Ouest, commonly referred to as <Angers_SCO> or simply Angers , is a French professional football club based in Angers in Pays de la Loire in western <France>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers_SCO>
#         Entity 2: <France>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Angers> Sporting Club de l'Ouest, commonly referred to as <Angers_SCO> or simply Angers , is a French professional football club based in Angers in Pays de la Loire in western <France>. The club was founded in <1919-01-01T00:00:00Z> and plays in Ligue 1, the first division of Football in France, having achieved promotion to the league in 2015 after 21 years.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers_SCO>
#         Entity 2: <1919-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#   Processing <Angers__u0028_meteorite_u0029_> 164
#
#         Context: <Angers__u0028_meteorite_u0029_> is an L6 meteorite that hit Pays de la Loire, <France> in 1822. <Angers__u0028_meteorite_u0029_> is an L6 meteorite that hit Pays de la Loire, <France> in 1822.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers__u0028_meteorite_u0029_>
#         Entity 2: <France>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Angers> 165
#
#         Context: <Maine__u0028_river_u0029_>, the castle, and the spires of the cathedral Angers (, ,<Angers> (US) and ) is a city in western <France>, about southwest of Paris. <Maine__u0028_river_u0029_>, the castle, and the spires of the cathedral Angers (, ,<Angers> (US) and ) is a city in western <France>, about southwest of Paris.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers>
#         Entity 2: <Maine__u0028_river_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Maine__u0028_river_u0029_>, the castle, and the spires of the cathedral Angers (, ,<Angers> (US) and ) is a city in western <France>, about southwest of Paris. <Maine__u0028_river_u0029_>, the castle, and the spires of the cathedral Angers (, ,<Angers> (US) and ) is a city in western <France>, about southwest of Paris.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers>
#         Entity 2: <France>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Maine__u0028_river_u0029_>, the castle, and the spires of the cathedral Angers (, ,<Angers> (US) and ) is a city in western <France>, about southwest of Paris. Angers developed at the confluence of three rivers, the <Mayenne__u0028_river_u0029_>, the <Sarthe__u0028_river_u0029_>, and the Loir, all coming from the north and flowing south to the Loire.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers>
#         Entity 2: <Mayenne__u0028_river_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Maine__u0028_river_u0029_>, the castle, and the spires of the cathedral Angers (, ,<Angers> (US) and ) is a city in western <France>, about southwest of Paris. Angers developed at the confluence of three rivers, the <Mayenne__u0028_river_u0029_>, the <Sarthe__u0028_river_u0029_>, and the Loir, all coming from the north and flowing south to the Loire.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Angers>
#         Entity 2: <Sarthe__u0028_river_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Disraeli_u002C__Quebec__u0028_parish_u0029_> 166
#
#         Context: The parish of <Disraeli_u002C__Quebec__u0028_parish_u0029_> is located in the <Les_Appalaches_Regional_County_Municipality> in the Chaudière-Appalaches region of Quebec, <Canada>. The parish of <Disraeli_u002C__Quebec__u0028_parish_u0029_> is located in the <Les_Appalaches_Regional_County_Municipality> in the Chaudière-Appalaches region of Quebec, <Canada>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli_u002C__Quebec__u0028_parish_u0029_>
#         Entity 2: <Les_Appalaches_Regional_County_Municipality>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: The parish of <Disraeli_u002C__Quebec__u0028_parish_u0029_> is located in the <Les_Appalaches_Regional_County_Municipality> in the Chaudière-Appalaches region of Quebec, <Canada>. The parish of <Disraeli_u002C__Quebec__u0028_parish_u0029_> is located in the <Les_Appalaches_Regional_County_Municipality> in the Chaudière-Appalaches region of Quebec, <Canada>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli_u002C__Quebec__u0028_parish_u0029_>
#         Entity 2: <Canada>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: The parish of <Disraeli_u002C__Quebec__u0028_parish_u0029_> is located in the <Les_Appalaches_Regional_County_Municipality> in the Chaudière-Appalaches region of Quebec, <Canada>. It was named after British statesman and writer Benjamin <Disraeli_u002C__Quebec__u0028_city_u0029_>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli_u002C__Quebec__u0028_parish_u0029_>
#         Entity 2: <Disraeli_u002C__Quebec__u0028_city_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Disraeli__u0028_play_u0029_> 167
#
#         Context: <Disraeli__u0028_play_u0029_> is a biographical play by the British writer <Louis_N_u002E__Parker>, which was first staged in 1911. <Disraeli__u0028_play_u0029_> is a biographical play by the British writer <Louis_N_u002E__Parker>, which was first staged in 1911.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_play_u0029_>
#         Entity 2: <Louis_N_u002E__Parker>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Disraeli__u0028_play_u0029_> is a biographical play by the British writer <Louis_N_u002E__Parker>, which was first staged in 1911. The play was commissioned by the actor George Arliss who saw a portrayal of the Victorian British statesman Benjamin Disraeli as an ideal vehicle for his stage career.Fells p.25-26 It was written in <London> during 1910.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_play_u0029_>
#         Entity 2: <London>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Disraeli__u0028_1916_film_u0029_> 168
#
#         Context: <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>. <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1916_film_u0029_>
#         Entity 2: <Charles_Calvert__u0028_director_u0029_>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>. <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1916_film_u0029_>
#         Entity 2: <Percy_Nash>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>. <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1916_film_u0029_>
#         Entity 2: <Dennis_Eadie>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>. <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1916_film_u0029_>
#         Entity 2: <Mary_Jerrold>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>. <Disraeli__u0028_1916_film_u0029_> is a 1916 British silent biographical film directed by <Charles_Calvert__u0028_director_u0029_> and <Percy_Nash> and starring <Dennis_Eadie>, <Mary_Jerrold> and <Cyril_Raymond>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1916_film_u0029_>
#         Entity 2: <Cyril_Raymond>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Disraeli__u0028_1929_film_u0029_> 169
#
#         Context: <Disraeli__u0028_1929_film_u0029_> is a 1929 American historical film directed by <Alfred_E_u002E__Green>, released by Warner Bros. <Disraeli__u0028_1929_film_u0029_> is a 1929 American historical film directed by <Alfred_E_u002E__Green>, released by Warner Bros.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1929_film_u0029_>
#         Entity 2: <Alfred_E_u002E__Green>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Disraeli__u0028_1929_film_u0029_> is a 1929 American historical film directed by <Alfred_E_u002E__Green>, released by Warner Bros. <George_Arliss> in his greatest picture Disraeli".
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Disraeli__u0028_1929_film_u0029_>
#         Entity 2: <George_Arliss>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Disraeli__u0028_TV_serial_u0029_> 170
#
#         Context: <Disraeli__u0028_TV_serial_u0029_> is a British four-part serial about the great statesman and Prime Minister of the United Kingdom, Benjamin Disraeli. With a screenplay by David Butler, it was produced by Cecil Clarke and directed by <Claude_Whatham>.
#
#         Task: Identify the relationship between the following entities.
#
# ...
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_1980_film_u0029_>
#         Entity 2: <New_Jersey>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_1980_film_u0029_> is a 1980 American slasher film produced and directed by <Sean_S_u002E__Cunningham>, written by Victor Miller, and starring <Betsy_Palmer>, <Adrienne_King>, <Harry_Crosby__u0028_businessman_u0029_>, <Laurie_Bartram>, Mark Nelson, <Jeannine_Taylor>, Robbi Morgan, and <Kevin_Bacon>. A bidding war ensued over the finished film, ending with <Paramount_Pictures> acquiring the film for domestic distribution, while Warner Bros.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_1980_film_u0029_>
#         Entity 2: <Paramount_Pictures>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Friday_the_13th__u0028_1916_film_u0029_> 398
#
#         Context: <Friday_the_13th__u0028_1916_film_u0029_> [aka Friday the Thirteenth] is a lostThe Library of Congress/FIAF American Silent Feature Film Survival Catalog:Friday the 13th <1916-01-01T00:00:00Z> silent film drama directed by <Émile_Chautard> and starring <Robert_Warwick>. <Friday_the_13th__u0028_1916_film_u0029_> [aka Friday the Thirteenth] is a lostThe Library of Congress/FIAF American Silent Feature Film Survival Catalog:Friday the 13th <1916-01-01T00:00:00Z> silent film drama directed by <Émile_Chautard> and starring <Robert_Warwick>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_1916_film_u0029_>
#         Entity 2: <1916-01-01T00:00:00Z>
#
#         Relation (choose from [<deathDate>, <dateCreated>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_1916_film_u0029_> [aka Friday the Thirteenth] is a lostThe Library of Congress/FIAF American Silent Feature Film Survival Catalog:Friday the 13th <1916-01-01T00:00:00Z> silent film drama directed by <Émile_Chautard> and starring <Robert_Warwick>. <Friday_the_13th__u0028_1916_film_u0029_> [aka Friday the Thirteenth] is a lostThe Library of Congress/FIAF American Silent Feature Film Survival Catalog:Friday the 13th <1916-01-01T00:00:00Z> silent film drama directed by <Émile_Chautard> and starring <Robert_Warwick>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_1916_film_u0029_>
#         Entity 2: <Émile_Chautard>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_1916_film_u0029_> [aka Friday the Thirteenth] is a lostThe Library of Congress/FIAF American Silent Feature Film Survival Catalog:Friday the 13th <1916-01-01T00:00:00Z> silent film drama directed by <Émile_Chautard> and starring <Robert_Warwick>. <Friday_the_13th__u0028_1916_film_u0029_> [aka Friday the Thirteenth] is a lostThe Library of Congress/FIAF American Silent Feature Film Survival Catalog:Friday the 13th <1916-01-01T00:00:00Z> silent film drama directed by <Émile_Chautard> and starring <Robert_Warwick>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_1916_film_u0029_>
#         Entity 2: <Robert_Warwick>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#   Processing <Friday_the_13th__u0028_2009_film_u0029_> 399
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Marcus_Nispel>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. The film was produced by <Platinum_Dunes> and Crystal Lake Entertainment and distributed by <New_Line_Cinema> and <Paramount_Pictures>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Platinum_Dunes>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. The film was produced by <Platinum_Dunes> and Crystal Lake Entertainment and distributed by <New_Line_Cinema> and <Paramount_Pictures>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <New_Line_Cinema>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. The film was produced by <Platinum_Dunes> and Crystal Lake Entertainment and distributed by <New_Line_Cinema> and <Paramount_Pictures>.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Paramount_Pictures>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. It stars <Jared_Padalecki>, <Danielle_Panabaker>, <Aaron_Yoo>, <Amanda_Righetti>, <Travis_Van_Winkle>, and <Derek_Mears> and follows Clay Miller (Padalecki) as he searches for his missing sister, Whitney (Righetti), who is captured by Jason Voorhees (Mears) while camping in woodland at Crystal Lake.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Jared_Padalecki>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. It stars <Jared_Padalecki>, <Danielle_Panabaker>, <Aaron_Yoo>, <Amanda_Righetti>, <Travis_Van_Winkle>, and <Derek_Mears> and follows Clay Miller (Padalecki) as he searches for his missing sister, Whitney (Righetti), who is captured by Jason Voorhees (Mears) while camping in woodland at Crystal Lake.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Danielle_Panabaker>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. It stars <Jared_Padalecki>, <Danielle_Panabaker>, <Aaron_Yoo>, <Amanda_Righetti>, <Travis_Van_Winkle>, and <Derek_Mears> and follows Clay Miller (Padalecki) as he searches for his missing sister, Whitney (Righetti), who is captured by Jason Voorhees (Mears) while camping in woodland at Crystal Lake.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Aaron_Yoo>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. It stars <Jared_Padalecki>, <Danielle_Panabaker>, <Aaron_Yoo>, <Amanda_Righetti>, <Travis_Van_Winkle>, and <Derek_Mears> and follows Clay Miller (Padalecki) as he searches for his missing sister, Whitney (Righetti), who is captured by Jason Voorhees (Mears) while camping in woodland at Crystal Lake.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Amanda_Righetti>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. It stars <Jared_Padalecki>, <Danielle_Panabaker>, <Aaron_Yoo>, <Amanda_Righetti>, <Travis_Van_Winkle>, and <Derek_Mears> and follows Clay Miller (Padalecki) as he searches for his missing sister, Whitney (Righetti), who is captured by Jason Voorhees (Mears) while camping in woodland at Crystal Lake.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Travis_Van_Winkle>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. It stars <Jared_Padalecki>, <Danielle_Panabaker>, <Aaron_Yoo>, <Amanda_Righetti>, <Travis_Van_Winkle>, and <Derek_Mears> and follows Clay Miller (Padalecki) as he searches for his missing sister, Whitney (Righetti), who is captured by Jason Voorhees (Mears) while camping in woodland at Crystal Lake.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <Derek_Mears>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
#
#         Context: <Friday_the_13th__u0028_2009_film_u0029_> is a 2009 American slasher film directed by <Marcus_Nispel> and written by Damian Shannon and Mark Swift from a screen story by Shannon, Swift and Mark Wheaton. Friday the 13th was theatrically released in <United_States> on February 13, 2009, by New Line Cinema in North American territories and by Paramount Pictures internationally.
#
#         Task: Identify the relationship between the following entities.
#
#         Entity 1: <Friday_the_13th__u0028_2009_film_u0029_>
#         Entity 2: <United_States>
#
#         Relation (choose from [<birthPlace>, <founder>, <worksFor>, <appearsIn>, <musicBy>, <actor>, <productionCompany>, <playsIn>, <author>, <director>, <alumniOf>, <homeLocation>, <memberOf>, <contentLocation>, <location>, <owns>, <locationCreated>, <manufacturer>, <neighbors>, <deathPlace>, <deathDate>, <children>, <nationality>, <award>, <dateCreated>, <about>, <birthDate>]):
# done
# execution time:  514.0370161533356
# number of articles:  399

# %%
run_evaluation()
# Out:
# You classified the relation between <Ashok_Kumar__u0028_Indian_politician_u0029_> and <Indian_National_Congress> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Ashok_Kumar__u0028_golfer_u0029_> and <Bihar> wrong. Expected output:  <birthPlace> ,given: <alumniOf>
# You classified the relation between <Ashok_Kumar_Dogra> and <Indian_National_Congress> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Ashok_Kumar> and <India> wrong. Expected output:  <nationality> ,given: <actor>
# You classified the relation between <Ashok_Kumar_Garg> and <India> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Ashok_Kumar__u0028_British_politician_u0029_> and <Labour_Party__u0028_UK_u0029_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Ashok_Kumar__u0028_cinematographer_u0029_> and <Allahabad> wrong. Expected output:  <birthPlace> ,given: <homeLocation>
# You classified the relation between <Ashok_Kumar__u0028_cinematographer_u0029_> and <Chennai> wrong. Expected output:  <deathPlace> ,given: <alumniOf>
# You classified the relation between <Mortal_Kombat__u0028_2011_video_game_u0029_> and <NetherRealm_Studios> wrong. Expected output:  <manufacturer> ,given: <productionCompany>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Ludi_Lin> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Joe_Taslim> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Tadanobu_Asano> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Jessica_McNamee> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Mehcad_Brooks> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Josh_Lawson> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <Hiroyuki_Sanada> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <United_States> wrong. Expected output:  <locationCreated> ,given: <productionCompany>
# You classified the relation between <Mortal_Kombat__u0028_1995_film_u0029_> and <Linden_Ashby> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Mortal_Kombat__u0028_1995_film_u0029_> and <Bridgette_Wilson> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Epirus__u0028_ancient_state_u0029_> and <Epirus> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Epirus> and <Greece> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Epirus> and <Albania> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Marble_Canyon__u0028_British_Columbia_u0029_> and <British_Columbia> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Marble_Canyon__u0028_Canadian_Rockies_u0029_> and <Canada> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Marble_Canyon_u002C__Arizona> and <Coconino_County_u002C__Arizona> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Marble_Canyon_u002C__Arizona> and <United_States> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Marble_Canyon> and <Arizona> wrong. Expected output:  <location> ,given: <alumniOf>
# You classified the relation between <Foxfire_u002C__North_Carolina> and <Moore_County_u002C__North_Carolina> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Foxfire_u002C__North_Carolina> and <United_States> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Foxfire__u0028_1955_film_u0029_> and <Jane_Russell> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Foxfire__u0028_1955_film_u0029_> and <Jeff_Chandler> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Foxfire__u0028_1955_film_u0029_> and <Dan_Duryea> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Battleaxe__u0028_band_u0029_> and <Sunderland> wrong. Expected output:  <locationCreated> ,given: <homeLocation>
# You classified the relation between <Shaolin_Temple__u0028_1982_film_u0029_> and <British_Hong_Kong> wrong. Expected output:  <locationCreated> ,given: <homeLocation>
# You classified the relation between <Shaolin_Temple__u0028_1982_film_u0029_> and <China> wrong. Expected output:  <locationCreated> ,given: <appearsIn>
# You classified the relation between <Shaolin_Wooden_Men> and <Hong_Kong> wrong. Expected output:  <locationCreated> ,given: <homeLocation>
# You classified the relation between <Kralovice> and <Czech_Republic> wrong. Expected output:  <location> ,given: <birthPlace>
# You classified the relation between <Královice__u0028_Prague_u0029_> and <Czech_Republic> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Královice__u0028_Kladno_District_u0029_> and <Czech_Republic> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Královice__u0028_Kladno_District_u0029_> and <Slaný> wrong. Expected output:  <neighbors> ,given: <homeLocation>
# You classified the relation between <Mike_Shanahan> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Mike_Shanahan__u0028_ice_hockey_u0029_> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Mike_Shanahan__u0028_ice_hockey_u0029_> and <St_u002E__Louis_Blues> wrong. Expected output:  <owns> ,given: <alumniOf>
# You classified the relation between <Mike_Shanahan__u0028_ice_hockey_u0029_> and <University_City_u002C__Missouri> wrong. Expected output:  <birthPlace> ,given: <alumniOf>
# You classified the relation between <Mike_Shanahan__u0028_tight_end_u0029_> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Calla__u0028_band_u0029_> and <New_York_City> wrong. Expected output:  <locationCreated> ,given: <homeLocation>
# You classified the relation between <Calla_u002C__Ohio> and <Mahoning_County_u002C__Ohio> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Mark_Wilkinson__u0028_rugby_union_u0029_> and <Newcastle_Falcons> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Ramsgate> and <Thanet_District> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Ramsgate_u002C__New_South_Wales> and <New_South_Wales> wrong. Expected output:  <location> ,given: <birthPlace>
# You classified the relation between <Ring_Road__u0028_Kathmandu_u0029_> and <Lalitpur_District_u002C__Nepal> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <London_Inner_Ring_Road> and <City_of_London> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Ring_Road__u0028_Regina_u002C__Saskatchewan_u0029_> and <Canada> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Ring_Road__u0028_Cairo_u0029_> and <Egypt> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Route_1__u0028_Iceland_u0029_> and <Iceland> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Geordie__u0028_band_u0029_> and <Newcastle_upon_Tyne> wrong. Expected output:  <locationCreated> ,given: <homeLocation>
# You classified the relation between <Jerry_Adler__u0028_harmonica_player_u0029_> and <Baltimore> wrong. Expected output:  <birthPlace> ,given: <homeLocation>
# You classified the relation between <Jerry_Adler> and <United_States> wrong. Expected output:  <nationality> ,given: <actor>
# You classified the relation between <Jerry_Adler__u0028_rock_musician_u0029_> and <New_York_City> wrong. Expected output:  <birthPlace> ,given: <homeLocation>
# You classified the relation between <Splinter__u0028_2008_film_u0029_> and <Paulo_Costanzo> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Splinter__u0028_2008_film_u0029_> and <Jill_Wagner> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Splinter__u0028_2008_film_u0029_> and <Oklahoma> wrong. Expected output:  <contentLocation> ,given: <homeLocation>
# You classified the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_IDW_Publishing_u0029_> wrong. Expected output:  <appearsIn> ,given: <productionCompany>
# You classified the relation between <Splinter__u0028_2006_film_u0029_> and <Los_Angeles> wrong. Expected output:  <contentLocation> ,given: <homeLocation>
# You classified the relation between <Splinter__u0028_2006_film_u0029_> and <Tom_Sizemore> wrong. Expected output:  <actor> ,given: <appearsIn>
# You classified the relation between <Splinter__u0028_2006_film_u0029_> and <Edward_James_Olmos> wrong. Expected output:  <actor> ,given: <alumniOf>
# You classified the relation between <Splinter__u0028_2006_film_u0029_> and <United_States> wrong. Expected output:  <locationCreated> ,given: <appearsIn>
# You classified the relation between <Splinter__u0028_band_u0029_> and <1974-01-01T00:00:00Z> wrong. Expected output:  <dateCreated> ,given: <birthDate>
# You classified the relation between <Dalston_u002C__Cumbria> and <City_of_Carlisle> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Dalston__u0028_Hackney_ward_u0029_> and <London_Borough_of_Hackney> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Lori_Fullington> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_basketball_u0029_> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_basketball_u0029_> and <Baloncesto_Málaga> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_baseball_u0029_> and <Major_League_Baseball> wrong. Expected output:  <playsIn> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_baseball_u0029_> and <Baltimore_Orioles> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_L_u002E__Roberts> and <Comcast> wrong. Expected output:  <worksFor> ,given: <founder>
# You classified the relation between <Brian_Roberts__u0028_English_footballer_u0029_> and <Coventry_City_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_English_footballer_u0029_> and <Hereford_United_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_English_footballer_u0029_> and <Birmingham_City_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_English_footballer_u0029_> and <Wolverhampton_Wanderers_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_soccer_u0029_> and <Los_Angeles> wrong. Expected output:  <birthPlace> ,given: <homeLocation>
# You classified the relation between <Brian_Roberts__u0028_soccer_u0029_> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_soccer_u0029_> and <Sporting_Kansas_City> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Brian_Roberts__u0028_Australian_rules_footballer_u0029_> and <Richmond_Football_Club> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Key_West> and <Stock_Island_u002C__Florida> wrong. Expected output:  <neighbors> ,given: <location>
# You classified the relation between <Key_West_u002C__Minnesota> and <Polk_County_u002C__Minnesota> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Key_West__u0028_film_u0029_> and <1973-01-01T00:00:00Z> wrong. Expected output:  <dateCreated> ,given: <birthDate>
# You classified the relation between <Key_West_u002C__Virginia> and <Albemarle_County_u002C__Virginia> wrong. Expected output:  <location> ,given: <homeLocation>
# You classified the relation between <Serpico> and <Frank_Serpico> wrong. Expected output:  <about> ,given: <alumniOf>
# You classified the relation between <Joe_Wright__u0028_footballer_u002C__born_1907_u0029_> and <Leicester_City_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Joe_Wright__u0028_basketball_u0029_> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You classified the relation between <Joe_Wright__u0028_baseball_u0029_> and <Pittsburgh_Pirates> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Galahad_u002C__Alberta> and <Canada> wrong. Expected output:  <location> ,given: <nationality>
# You classified the relation between <Alexander_Thom__u0028_footballer_u0029_> and <Kilmarnock_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Alexander_Thom__u0028_footballer_u0029_> and <Ayr_United_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Alexander_Thom__u0028_footballer_u0029_> and <Motherwell_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Alexander_Thom__u0028_footballer_u0029_> and <Hull_City_A_u002E_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Alexander_Thom__u0028_footballer_u0029_> and <Swindon_Town_F_u002E_C_u002E_> wrong. Expected output:  <memberOf> ,given: <alumniOf>
# You classified the relation between <Keith_Anderson> and <United_States> wrong. Expected output:  <nationality> ,given: <alumniOf>
# You did not classify the relation between <Mortal_Kombat__u0028_2021_film_u0029_> and <2021-01-01T00:00:00Z>.
# You did not classify the relation between <Mortal_Kombat__u0028_1995_film_u0029_> and <1995-08-18T00:00:00Z>.
# You did not classify the relation between <Mortal_Kombat__u0028_1995_film_u0029_> and <United_States>.
# You did not classify the relation between <Foxfire__u0028_1987_film_u0029_> and <1987-01-01T00:00:00Z>.
# You did not classify the relation between <Calla_u002C__Ohio> and <United_States>.
# You did not classify the relation between <Ring_Road__u0028_song_u0029_> and <2008-07-06T00:00:00Z>.
# You did not classify the relation between <Splinter__u0028_2008_film_u0029_> and <2008-01-01T00:00:00Z>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles_u003A__Out_of_the_Shadows>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <TMNT__u0028_film_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_Mirage_Studios_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_Dreamwave_Productions_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_2012_TV_series_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_1990_film_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_2003_TV_series_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_1987_TV_series_u0029_>.
# You did not classify the relation between <Splinter__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_2014_film_u0029_>.
# You did not classify the relation between <Key_West> and <United_States>.
# You did not classify the relation between <Key_West_u002C__Minnesota> and <United_States>.
# You did not classify the relation between <Joe_Wright__u0028_rower_u0029_> and <1992-03-14T00:00:00Z>.
# You did not classify the relation between <Clinton_u002C__Arkansas> and <United_States>.
# You did not classify the relation between <Clinton_u002C__Indiana> and <United_States>.
# You did not classify the relation between <Graphite__u0028_album_u0029_> and <1999-01-01T00:00:00Z>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_comic_strip_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_1987_TV_series_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_2014_film_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_IDW_Publishing_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles_u003A__Out_of_the_Shadows>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_Dreamwave_Productions_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <TMNT__u0028_film_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_2012_TV_series_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_1990_film_u0029_>.
# You did not classify the relation between <Michelangelo__u0028_Teenage_Mutant_Ninja_Turtles_u0029_> and <Teenage_Mutant_Ninja_Turtles__u0028_2003_TV_series_u0029_>.
# You did not classify the relation between <Material__u0028_Blaqk_Audio_album_u0029_> and <2016-04-15T00:00:00Z>.
# You did not classify the relation between <Material__u0028_Aco_album_u0029_> and <2001-01-01T00:00:00Z>.
#
# Scores (scaled from 0 to 100)
# Precision 42.90780141843972
# Recall 78.06451612903226
# F-0.5 Score 47.155105222135624
